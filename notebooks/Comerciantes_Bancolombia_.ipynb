# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelreal90/Segmentacion-de-Comerciantes/blob/main/notebooks/Comerciantes_Bancolombia_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Proyecto de Comerciantes de la entidad bancaria Bancolombia(Norte de Satander)
# Explorando mi curiosidad y motivado por la vasta cantidad de datos abiertos disponibles en Colombia, me sumergí en la fascinante tarea de analizar una base de datos específica relacionada con empresas en el departamento de Norte de Santander(https://www.datos.gov.co/Comercio-Industria-y-Turismo/BASE-DE-DATOS-EMPRESAS-DE-NORTE-DE-SANTANDER/w98a-ssvz/about_data). Dada la amplitud de la información, tomé la decisión de focalizar mi atención en una entidad bancaria en particular: Bancolombia.
#
# Este enfoque selectivo permitirá una exploración detallada y específica de los datos asociados con Bancolombia en la región, proporcionando una visión más precisa y detallada de la dinámica empresarial en el departamento. A través de esta investigación, busco desentrañar patrones, identificar tendencias y extraer conocimientos valiosos que puedan contribuir a una comprensión más profunda de la actividad económica en esta área geográfica.
#
# Este proyecto no solo representa un viaje de descubrimiento en el vasto mundo de los datos abiertos, sino también una oportunidad para aplicar herramientas avanzadas de machine learning y analítica de datos con el objetivo de obtener insights significativos y beneficios tangibles en el contexto empresarial de Norte de Santander

# %%
import pandas as pd
df_bancolombia=pd.read_csv('datos_Bancolombia.csv')
df_bancolombia.head()
# Out:
#    Tipo_Entidad          Nombre_Tipo_Entidad  Codigo_Entidad Nombre_Entidad  \
# 0             1  BC-ESTABLECIMIENTO BANCARIO             7.0    Bancolombia
# 1             1  BC-ESTABLECIMIENTO BANCARIO             7.0    Bancolombia
# 2             1  BC-ESTABLECIMIENTO BANCARIO             7.0    Bancolombia
# 3             1  BC-ESTABLECIMIENTO BANCARIO             7.0    Bancolombia
# 4             1  BC-ESTABLECIMIENTO BANCARIO             7.0    Bancolombia
#
#   Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# 0  01/12/2023        Jurídica  No aplica   Mediana empresa
# 1  20/10/2023         Natural   Femenino         No aplica
# 2  01/12/2023         Natural   Femenino         No aplica
# 3  29/09/2023         Natural  Masculino         No aplica
# 4  24/11/2023        Jurídica  No aplica   Mediana empresa
#
#        Tipo_de_crédito             Tipo_de_garantía  ...  \
# 0  Comercial ordinario  Garantia idónea o no idónea  ...
# 1              Consumo  Garantia idónea o no idónea  ...
# 2              Consumo                 Sin garantia  ...
# 3              Consumo                 Sin garantia  ...
# 4  Comercial ordinario  Garantia idónea o no idónea  ...
#
#   Tasa_efectiva_promedio_ponderada margen_adicional  Montos_desembolsados  \
# 0                            38.21              0.0            3538866.93
# 1                            39.79              0.0             480291.09
# 2                            38.21              0.0             353840.00
# 3                             0.00              0.0           14806418.00
# 4                            38.26              0.0           76230556.86
#
#    Numero_de_creditos_desembolsados  Antiguedad_de_la_empresa  Tipo_de_Tasa  \
# 0                               5.0                0 a 5 años            FS
# 1                               2.0              No aplica(1)            FS
# 2                               1.0              No aplica(1)            FS
# 3                              29.0              No aplica(1)            FS
# 4                              10.0            más de 10 años            FS
#
#                       Rango_monto_desembolsado          Clase_deudor  \
# 0      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 1                                Hasta 1 SMLMV  Deudor de la entidad
# 2                                Hasta 1 SMLMV  Deudor de la entidad
# 3      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 4  Mayor a 12 SMLMV y menor o igual a 25 SMLMV  Deudor de la entidad
#
#   Codigo_CIIU Codigo_Municipio
# 0      8544.0          11001.0
# 1      8622.0           5154.0
# 2      5613.0          17001.0
# 3        90.0           5266.0
# 4      8010.0          11001.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Antes de fltrar los datos, se habian trabajado los valores nulos y duplicados, seguimos explorando los datos
# Sabiendo que ya estamos en Bancolobia borramos las columnas que identifican a Bancolombia ['Tipo_Entidad','Nombre_Tipo_Entidad','Codigo_Entidad','Nombre_Entidad']

# %%
columnas_a_eliminar = ['Tipo_Entidad','Nombre_Tipo_Entidad','Codigo_Entidad','Nombre_Entidad']

# Utiliza el método drop para eliminar las columnas
df_bancolombia = df_bancolombia.drop(columnas_a_eliminar, axis=1)
df_bancolombia.head()
# Out:
#   Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# 0  01/12/2023        Jurídica  No aplica   Mediana empresa
# 1  20/10/2023         Natural   Femenino         No aplica
# 2  01/12/2023         Natural   Femenino         No aplica
# 3  29/09/2023         Natural  Masculino         No aplica
# 4  24/11/2023        Jurídica  No aplica   Mediana empresa
#
#        Tipo_de_crédito             Tipo_de_garantía  \
# 0  Comercial ordinario  Garantia idónea o no idónea
# 1              Consumo  Garantia idónea o no idónea
# 2              Consumo                 Sin garantia
# 3              Consumo                 Sin garantia
# 4  Comercial ordinario  Garantia idónea o no idónea
#
#                                  Producto de crédito  \
# 0                     Tarjeta de crédito empresarial
# 1      Sobregiro en cuenta corriente persona natural
# 2  Tarjeta de crédito para ingresos superiores a ...
# 3  Tarjeta de crédito para ingresos superiores a ...
# 4  Sobregiro en cuenta corriente persona jurídica...
#
#                Plazo de crédito  Tasa_efectiva_promedio_ponderada  \
# 0  Consumos entre 25 y 36 meses                             38.21
# 1                 Hasta 30 días                             39.79
# 2    Consumos entre 2 y 6 meses                             38.21
# 3             Consumos a un mes                              0.00
# 4                 Hasta 30 días                             38.26
#
#    margen_adicional  Montos_desembolsados  Numero_de_creditos_desembolsados  \
# 0               0.0            3538866.93                               5.0
# 1               0.0             480291.09                               2.0
# 2               0.0             353840.00                               1.0
# 3               0.0           14806418.00                              29.0
# 4               0.0           76230556.86                              10.0
#
#   Antiguedad_de_la_empresa Tipo_de_Tasa  \
# 0               0 a 5 años           FS
# 1             No aplica(1)           FS
# 2             No aplica(1)           FS
# 3             No aplica(1)           FS
# 4           más de 10 años           FS
#
#                       Rango_monto_desembolsado          Clase_deudor  \
# 0      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 1                                Hasta 1 SMLMV  Deudor de la entidad
# 2                                Hasta 1 SMLMV  Deudor de la entidad
# 3      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 4  Mayor a 12 SMLMV y menor o igual a 25 SMLMV  Deudor de la entidad
#
#    Codigo_CIIU  Codigo_Municipio
# 0       8544.0           11001.0
# 1       8622.0            5154.0
# 2       5613.0           17001.0
# 3         90.0            5266.0
# 4       8010.0           11001.0

# %%
df_bancolombia.isnull().sum()
# Out:
# Fecha_Corte                         1
# Tipo_de_persona                     1
# Sexo                                1
# Tamaño_de_empresa                   1
# Tipo_de_crédito                     1
# Tipo_de_garantía                    1
# Producto de crédito                 1
# Plazo de crédito                    1
# Tasa_efectiva_promedio_ponderada    1
# margen_adicional                    1
# Montos_desembolsados                1
# Numero_de_creditos_desembolsados    1
# Antiguedad_de_la_empresa            1
# Tipo_de_Tasa                        1
# Rango_monto_desembolsado            1
# Clase_deudor                        1
# Codigo_CIIU                         1
# Codigo_Municipio                    1
# dtype: int64

# %%
df_bancolombia=df_bancolombia.dropna()

# %%
# Convierte la columna de flotantes a enteros
df_bancolombia['Codigo_CIIU'] = df_bancolombia['Codigo_CIIU'].astype(int)
df_bancolombia.head()
# Out:
#   Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# 0  01/12/2023        Jurídica  No aplica   Mediana empresa
# 1  20/10/2023         Natural   Femenino         No aplica
# 2  01/12/2023         Natural   Femenino         No aplica
# 3  29/09/2023         Natural  Masculino         No aplica
# 4  24/11/2023        Jurídica  No aplica   Mediana empresa
#
#        Tipo_de_crédito             Tipo_de_garantía  \
# 0  Comercial ordinario  Garantia idónea o no idónea
# 1              Consumo  Garantia idónea o no idónea
# 2              Consumo                 Sin garantia
# 3              Consumo                 Sin garantia
# 4  Comercial ordinario  Garantia idónea o no idónea
#
#                                  Producto de crédito  \
# 0                     Tarjeta de crédito empresarial
# 1      Sobregiro en cuenta corriente persona natural
# 2  Tarjeta de crédito para ingresos superiores a ...
# 3  Tarjeta de crédito para ingresos superiores a ...
# 4  Sobregiro en cuenta corriente persona jurídica...
#
#                Plazo de crédito  Tasa_efectiva_promedio_ponderada  \
# 0  Consumos entre 25 y 36 meses                             38.21
# 1                 Hasta 30 días                             39.79
# 2    Consumos entre 2 y 6 meses                             38.21
# 3             Consumos a un mes                              0.00
# 4                 Hasta 30 días                             38.26
#
#    margen_adicional  Montos_desembolsados  Numero_de_creditos_desembolsados  \
# 0               0.0            3538866.93                               5.0
# 1               0.0             480291.09                               2.0
# 2               0.0             353840.00                               1.0
# 3               0.0           14806418.00                              29.0
# 4               0.0           76230556.86                              10.0
#
#   Antiguedad_de_la_empresa Tipo_de_Tasa  \
# 0               0 a 5 años           FS
# 1             No aplica(1)           FS
# 2             No aplica(1)           FS
# 3             No aplica(1)           FS
# 4           más de 10 años           FS
#
#                       Rango_monto_desembolsado          Clase_deudor  \
# 0      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 1                                Hasta 1 SMLMV  Deudor de la entidad
# 2                                Hasta 1 SMLMV  Deudor de la entidad
# 3      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 4  Mayor a 12 SMLMV y menor o igual a 25 SMLMV  Deudor de la entidad
#
#    Codigo_CIIU  Codigo_Municipio
# 0         8544           11001.0
# 1         8622            5154.0
# 2         5613           17001.0
# 3           90            5266.0
# 4         8010           11001.0

# %%
df_bancolombia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29302 entries, 0 to 29301
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Fecha_Corte                       29302 non-null  object
#  1   Tipo_de_persona                   29302 non-null  object
#  2   Sexo                              29302 non-null  object
#  3   Tamaño_de_empresa                 29302 non-null  object
#  4   Tipo_de_crédito                   29302 non-null  object
#  5   Tipo_de_garantía                  29302 non-null  object
#  6   Producto de crédito               29302 non-null  object
#  7   Plazo de crédito                  29302 non-null  object
#  8   Tasa_efectiva_promedio_ponderada  29302 non-null  float64
#  9   margen_adicional                  29302 non-null  float64
#  10  Montos_desembolsados              29302 non-null  float64
#  11  Numero_de_creditos_desembolsados  29302 non-null  int64
#  12  Antiguedad_de_la_empresa          29302 non-null  object
#  13  Tipo_de_Tasa                      29302 non-null  object
#  14  Rango_monto_desembolsado          29302 non-null  object
#  15  Clase_deudor                      29302 non-null  object
#  16  Codigo_CIIU                       29302 non-null  int64
#  17  Codigo_Municipio                  29302 non-null  float64
# dtypes: float64(4), int64(2), object(12)
# memory usage: 4.2+ MB

# %%
df_bancolombia.describe()
# Out:
#        Tasa_efectiva_promedio_ponderada  margen_adicional  \
# count                      29302.000000      29302.000000
# mean                          23.555378          0.366051
# std                           17.764558          2.224860
# min                            0.000000          0.000000
# 25%                            0.000000          0.000000
# 50%                           35.645000          0.000000
# 75%                           38.260000          0.000000
# max                           56.810000         27.510000
#
#        Montos_desembolsados  Numero_de_creditos_desembolsados   Codigo_CIIU  \
# count          2.930200e+04                      29302.000000  29302.000000
# mean           1.762778e+07                         25.341547   3902.982970
# std            3.347008e+08                       1094.512949   3119.890869
# min            6.200000e-01                          1.000000     10.000000
# 25%            2.261027e+05                          1.000000    111.000000
# 50%            1.003577e+06                          2.000000   4645.000000
# 75%            3.900000e+06                          4.000000   6311.000000
# max            4.166073e+10                     122868.000000   9900.000000
#
#        Codigo_Municipio
# count      29302.000000
# mean       31668.174493
# std        27701.338659
# min         5001.000000
# 25%         8001.000000
# 50%        18610.000000
# 75%        63001.000000
# max        99624.000000

# %% [markdown]
# ## Analisis de Distribucion

# %%
import matplotlib.pyplot as plt
import seaborn as sns
int_cols = df_bancolombia.select_dtypes(exclude='object').columns
for _ in int_cols:
    plt.figure(figsize=(10,10))
    sns.boxplot(data=df_bancolombia, y= _)
    plt.show()

# %%
df_Bancolombia_copia = df_bancolombia.copy()
columnas_a_eliminar = ['margen_adicional','Montos_desembolsados','Numero_de_creditos_desembolsados']

# Utiliza el método drop para eliminar las columnas
df_Bancolombia_copia =df_Bancolombia_copia.drop(columnas_a_eliminar, axis=1)
df_Bancolombia_copia.head()
# Out:
#   Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# 0  01/12/2023        Jurídica  No aplica   Mediana empresa
# 1  20/10/2023         Natural   Femenino         No aplica
# 2  01/12/2023         Natural   Femenino         No aplica
# 3  29/09/2023         Natural  Masculino         No aplica
# 4  24/11/2023        Jurídica  No aplica   Mediana empresa
#
#        Tipo_de_crédito             Tipo_de_garantía  \
# 0  Comercial ordinario  Garantia idónea o no idónea
# 1              Consumo  Garantia idónea o no idónea
# 2              Consumo                 Sin garantia
# 3              Consumo                 Sin garantia
# 4  Comercial ordinario  Garantia idónea o no idónea
#
#                                  Producto de crédito  \
# 0                     Tarjeta de crédito empresarial
# 1      Sobregiro en cuenta corriente persona natural
# 2  Tarjeta de crédito para ingresos superiores a ...
# 3  Tarjeta de crédito para ingresos superiores a ...
# 4  Sobregiro en cuenta corriente persona jurídica...
#
#                Plazo de crédito  Tasa_efectiva_promedio_ponderada  \
# 0  Consumos entre 25 y 36 meses                             38.21
# 1                 Hasta 30 días                             39.79
# 2    Consumos entre 2 y 6 meses                             38.21
# 3             Consumos a un mes                              0.00
# 4                 Hasta 30 días                             38.26
#
#   Antiguedad_de_la_empresa Tipo_de_Tasa  \
# 0               0 a 5 años           FS
# 1             No aplica(1)           FS
# 2             No aplica(1)           FS
# 3             No aplica(1)           FS
# 4           más de 10 años           FS
#
#                       Rango_monto_desembolsado          Clase_deudor  \
# 0      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 1                                Hasta 1 SMLMV  Deudor de la entidad
# 2                                Hasta 1 SMLMV  Deudor de la entidad
# 3      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 4  Mayor a 12 SMLMV y menor o igual a 25 SMLMV  Deudor de la entidad
#
#    Codigo_CIIU  Codigo_Municipio
# 0         8544           11001.0
# 1         8622            5154.0
# 2         5613           17001.0
# 3           90            5266.0
# 4         8010           11001.0

# %% [markdown]
# ## Exploramos los valores unicos de las variables tipo objeto

# %%
def mostrar_conteo_valores_objeto(dataframe):
    for columna in dataframe.select_dtypes(include='object').columns:
        conteo_valores = dataframe[columna].value_counts()
        print(f"Columna: {columna}")
        print(conteo_valores)
        print("------")
mostrar_conteo_valores_objeto(df_Bancolombia_copia)
# Out:
# Columna: Fecha_Corte
# 01/12/2023    8261
# 24/11/2023    8233
# 06/10/2023    8126
# 10/11/2023    7894
# 20/10/2023    7890
# 13/10/2023    7744
# 27/10/2023    7715
# 17/11/2023    7654
# 03/11/2023    7492
# 22/12/2023    3796
# 29/09/2023    3620
# 05/01/2024    1659
# 08/12/2023     257
# 15/12/2023     129
# 29/12/2023     125
# Name: Fecha_Corte, dtype: int64
# ------
# Columna: Tipo_de_persona
# Natural     55985
# Jurídica    24610
# Name: Tipo_de_persona, dtype: int64
# ------
# Columna: Sexo
# Masculino    31104
# Femenino     24881
# No aplica    24610
# Name: Sexo, dtype: int64
# ------
# Columna: Tamaño_de_empresa
# No aplica          55500
# Pequeña empresa     9033
# Microempresa        6718
# Mediana empresa     5325
# Gran empresa        4019
# Name: Tamaño_de_empresa, dtype: int64
# ------
# Columna: Tipo_de_crédito
# Consumo                                 55307
# Comercial ordinario                     24718
# Crédito productivo                        199
# Vivienda                                  193
# Comercial preferencial o corporativo      101
# Comercial especial                         60
# Comercial tesoreria                        17
# Name: Tipo_de_crédito, dtype: int64
# ------
# Columna: Tipo_de_garantía
# Garantia idónea o no idónea                                                            43297
# Sin garantia                                                                           37094
# Garantía  fondo nacional de garantías (FNG) o Fondo de Garantías de Antioquia (FGA)      146
# Garantía del fondo agropecuario de garantías (FAG)                                        58
# Name: Tipo_de_garantía, dtype: int64
# ------
# Columna: Producto de crédito
# Tarjeta de crédito para ingresos superiores a 2 SMMLV                    33026
# Tarjeta de crédito empresarial                                           15985
# Tarjeta de crédito para ingresos hasta 2 SMMLV                           13482
# Sobregiro en cuenta corriente persona jurídica o persona natural          5543
# Sobregiro en cuenta corriente persona natural                             4237
# Crédito rotativo                                                          2527
# Empresarial en pesos                                                      1666
# Factoring                                                                 1444
# Libre inversión                                                           1054
# Libranza otros                                                             461
# Vehículo                                                                   254
# Créditos de consumo de bajo monto                                          241
# Crédito popular productivo urbano (sin recursos de redescuento)            133
# Corporativo                                                                101
# Comerciales especiales establecidos mediante leyes                          60
# Adquisición de vivienda vis (colocación en uvr)                             58
# Adquisición de vivienda vis (colocación en pesos)                           56
# Crédito productivo urbano (sin recursos de redescuento)                     51
# Adquisición de vivienda no vis (colocación en pesos)                        49
# Comerciales con recursos provenientes de redescuento                        30
# Empresarial - Tesoreria                                                     17
# Créditos educativos diferentes a libranza                                   16
# Leasing financiero - otros                                                  15
# Adquisición de vivienda no vis (colocación en uvr)                          12
# Crédito productivo de mayor monto (sin recursos de redescuento)             12
# Construcción de vivienda individual no vis (colocación en pesos)            11
# Leasing financiero - financiación vehículos                                 11
# Leasing financiero - financiación maquinaria y equipo                       10
# Consumo empleados                                                            9
# Construcción de proyectos de vivienda vis (colocación en uvr)                5
# Construcción de vivienda individual vis (colocación en pesos)                4
# Leasing financiero - financiación inmuebles diferente de habitacional        4
# Construcción de proyectos de vivienda no vis (colocación en uvr)             3
# Crédito popular productivo rural (sin recursos de redescuento)               3
# Vivienda empleados                                                           2
# Construcción de vivienda individual no vis (colocación en uvr)               1
# Oficial o Gobierno                                                           1
# Financiero e institucional                                                   1
# Name: Producto de crédito, dtype: int64
# ------
# Columna: Plazo de crédito
# Consumos a un mes                 28542
# Avances en efectivo               11407
# Hasta 30 días                     10280
# Consumos entre 2 y 6 meses         9647
# Consumos entre 25 y 36 meses       9218
# Más de 3 años y hasta 5 años       2904
# Consumos entre 7 y 12 meses        2491
# Más de 30 días y hasta 1 año       2413
# Más de 1 año y hasta 3 años        1287
# Consumos entre 19 y 24 meses        781
# Más de 5 años y hasta 7 años        401
# Consumos entre 13 y 18 meses        351
# Más de 7 años y hasta 10 años       190
# Hasta 6 meses                       178
# Entre 31 días y 1 año               149
# Más de 15 años y hasta 20 años      124
# Consumos a más de 36 meses           56
# Más de 6 meses y hasta 1 año         53
# A más de 20 años                     50
# Más de 10 años                       31
# Más de 7 años y hasta 15 años        18
# A más de 7 años                      13
# Más de 1 año y hasta 2 años          10
# Vivienda hasta 5 años                 1
# Name: Plazo de crédito, dtype: int64
# ------
# Columna: Antiguedad_de_la_empresa
# No aplica(1)                55500
# más de 10 años              16303
# más de 5 y hasta 10 años     5699
# 0 a 5 años                   3093
# Name: Antiguedad_de_la_empresa, dtype: int64
# ------
# Columna: Tipo_de_Tasa
# FS     77347
# DTF     2948
# IB1      211
# IB6       55
# IB3       33
# IBE        1
# Name: Tipo_de_Tasa, dtype: int64
# ------
# Columna: Rango_monto_desembolsado
# Hasta 1 SMLMV                                    49989
# Mayor a 1 SMLMV menor o igual a 3 SMLMV          13182
# Mayor a 3 SMLMV menor o igual a 5 SMLMV           3496
# Mayor a 5 SMLMV menor o igual a 10 SMLMV          2218
# Mayor a 1 SMLMV y menor o igual a 3 SMLMV         1341
# Mayor a 3 SMLMV menor o igual a 6 SMLMV           1336
# Mayor a 6 SMLMV y menor o igual a 12 SMLMV        1304
# Mayor a 12 SMLMV y menor o igual a 25 SMLMV       1154
# Mayor a 3 SMLMV y menor o igual a 5 SMLMV         1126
# Mayor a 6 SMLMV menor o igual a 12 SMLMV           828
# Mayor a 25 SMLMV y menor o igual a 50 SMLMV        819
# Mayor a 10 SMLMV menor o igual a 20 SMLMV          702
# Mayor a 50 SMLMV y menor o igual a 100 SMLMV       478
# Mayor a 5 SMLMV y menor o igual a 6 SMLMV          459
# Mayor a 12 SMLMV menor o igual a 25 SMLMV          446
# Mayor a 20 SMLMV                                   285
# Mayor a 120 SMLMV y menor o igual a 240 SMLMV      264
# Mayor a 25 SMLMV menor o igual a 50 SMLMV          218
# Mayor a 240 SMLMV y menor o igual a 480 SMLMV      167
# Hasta 135 SMLMV                                    156
# Mayor a 50 SMLMV menor o igual a 100 SMLMV         123
# Mayor a 100 SMLMV y menor o igual a 120 SMLMV      121
# Mayor a 960 SMLMV                                   78
# Mayor a 480 SMLMV y menor o igual a 960 SMLMV       62
# Mayor a 3 SMLMV y menor o igual a 4 SMLMV           46
# Mayor a 1 SMLMV menor o igual a 2 SMLMV             34
# Mayor a 100 SMLMV menor o igual a 150 SMLMV         31
# Mayor a 4 SMLMV y menor o igual a 5 SMLMV           30
# Mayor a 135 SMLMV y menor o igual a 235 SMLMV       22
# Mayor a 150 SMLMV menor o igual a 300 SMLMV         21
# Mayor a 2 SMLMV menor o igual a 3 SMLMV              9
# Mayor a 1 SMLMV y menor o igual a 2 SMLMV            8
# Mayor a 335 SMLMV y menor o igual a 500 SMLMV        8
# Mayor a 2 SMLMV y menor o igual a 3 SMLMV            7
# Mayor a 25 SMLMV y menor o igual a 30 SMLMV          7
# Mayor a 235 SMLMV y menor o igual a 335 SMLMV        6
# Mayor a 30 SMLMV y menor o igual a 60 SMLMV          5
# Mayor a 3 SMLMV menor o igual a 4 SMLMV              3
# Mayor a 4 SMLMV menor o igual a 5 SMLMV              3
# Mayor 300 SMLMV                                      2
# Mayor a 500 SMLMV                                    1
# Name: Rango_monto_desembolsado, dtype: int64
# ------
# Columna: Clase_deudor
# Deudor de la entidad          76972
# Deudor nuevo en la entidad     3623
# Name: Clase_deudor, dtype: int64
# ------

# %% [markdown]
# ## convertimos algunas columnas a numericas

# %%
#convertir es Tipo_de_persona
#'Natural': 0, 'Jurídica': 1


# Crear un diccionario de mapeo
mapeo = {'Natural': 0, 'Jurídica': 1}

# Aplicar el mapeo a la columna Tipo_de_persona
df_Bancolombia_copia['Tipo_de_persona'] = df_Bancolombia_copia['Tipo_de_persona'].map(mapeo)
df_Bancolombia_copia['Tipo_de_persona'].value_counts()
# Out:
# 0    55985
# 1    24610
# Name: Tipo_de_persona, dtype: int64

# %%
#convertir columna Sexo
#'Masculino': 1, 'Femenino': 2, 'No aplica': 3, 'No binario': 4
# Crear un diccionario de mapeo
mapeo_sexo = {'Masculino': 1, 'Femenino': 2, 'No aplica': 3, 'No binario': 4}

# Aplicar el mapeo a la columna 'Sexo'
df_Bancolombia_copia['Sexo'] = df_Bancolombia_copia['Sexo'].map(mapeo_sexo)
df_Bancolombia_copia['Sexo'].value_counts()
# Out:
# 1    31104
# 2    24881
# 3    24610
# Name: Sexo, dtype: int64

# %%
#convertir columna Tamaño_de_empresa
# 'No aplica' : 1,'Pequeña empresa' : 2,'Microempresa' : 3,'Mediana empresa': 4,'Gran empresa' : 5
mapeo_Tamaño_de_empresa = {'No aplica' : 1,'Pequeña empresa' : 2,'Microempresa' : 3,'Mediana empresa': 4,'Gran empresa' : 5}

# Aplicar el mapeo a la columna 'Tamaño_de_empresa'
df_Bancolombia_copia['Tamaño_de_empresa'] = df_Bancolombia_copia['Tamaño_de_empresa'].map(mapeo_Tamaño_de_empresa)
df_Bancolombia_copia['Tamaño_de_empresa'].value_counts()
# Out:
# 1    55500
# 2     9033
# 3     6718
# 4     5325
# 5     4019
# Name: Tamaño_de_empresa, dtype: int64

# %%
#convertir columna Tipo_de_crédito
# 'Consumo' : 1,'Comercial ordinario' :2,'Vivienda' : 3,'Crédito productivo' : 4,'Comercial preferencial o corporativo' : 5,'Comercial especial' : 6,,'Comercial tesoreria':7
mapeo_Tipo_de_credito = {'Consumo' : 1,'Comercial ordinario' :2,'Vivienda' : 3,'Crédito productivo' : 4,
'Comercial preferencial o corporativo' : 5,'Comercial especial' : 6,'Comercial tesoreria':7}

# Aplicar el mapeo a la columna 'Tipo_de_crédito'
df_Bancolombia_copia['Tipo_de_crédito'] = df_Bancolombia_copia['Tipo_de_crédito'].map(mapeo_Tipo_de_credito)
df_Bancolombia_copia['Tipo_de_crédito'].value_counts()
# Out:
# 1    55307
# 2    24718
# 4      199
# 3      193
# 5      101
# 6       60
# 7       17
# Name: Tipo_de_crédito, dtype: int64

# %%
# convertir Columna Tipo_de_garantía
#'Garantia idónea o no idónea ' : 1,'Sin garantia' : 2,'Garantía  fondo nacional de garantías (FNG) o Fondo de Garantías de Antioquia (FGA)' : 3,'Garantía del fondo agropecuario de garantías (FAG)' : 4
mapeo_Tipo_de_garantía = {'Garantia idónea o no idónea' : 1 ,'Sin garantia' : 2 ,
'Garantía  fondo nacional de garantías (FNG) o Fondo de Garantías de Antioquia (FGA)' : 3 ,
'Garantía del fondo agropecuario de garantías (FAG)' : 4 }

# Aplicar el mapeo a la columna 'Tipo_de_garantía'
df_Bancolombia_copia['Tipo_de_garantía'] = df_Bancolombia_copia['Tipo_de_garantía'].map(mapeo_Tipo_de_garantía)
df_Bancolombia_copia['Tipo_de_garantía'].value_counts()
# Out:
# 1    43297
# 2    37094
# 3      146
# 4       58
# Name: Tipo_de_garantía, dtype: int64

# %%
#converit Columna Antiguedad_de_la_empresa
#'No aplica(1)' : 1,'más de 10 años' : 2,'más de 5 y hasta 10 años' : 3,'0 a 5 años' : 4
mapeo_Antiguedad_de_la_empresa = {'No aplica(1)' : 1,'más de 10 años' : 2,'más de 5 y hasta 10 años' : 3,'0 a 5 años' : 4}

# Aplicar el mapeo a la columna 'Antiguedad_de_la_empresa'
df_Bancolombia_copia['Antiguedad_de_la_empresa'] = df_Bancolombia_copia['Antiguedad_de_la_empresa'].map(mapeo_Antiguedad_de_la_empresa)
df_Bancolombia_copia['Antiguedad_de_la_empresa'].value_counts()
# Out:
# 1    55500
# 2    16303
# 3     5699
# 4     3093
# Name: Antiguedad_de_la_empresa, dtype: int64

# %%
# Convertir Columna Tipo_de_Tasa
#'FS' : 1,'DTF' : 2,'IB1' : 3,'IB6' : 4,'IB3' : 5,'IBE' : 6,'IPC' : 7,'IBR' : 8
mapeo_Tipo_de_Tasa = {'FS' : 1,'DTF' : 2,'IB1' : 3,'IB6' : 4,'IB3' : 5,'IBE' : 6,'IPC' : 7,'IBR' : 8}

# Aplicar el mapeo a la columna 'Tipo_de_Tasa'
df_Bancolombia_copia['Tipo_de_Tasa'] = df_Bancolombia_copia['Tipo_de_Tasa'].map(mapeo_Tipo_de_Tasa)
df_Bancolombia_copia['Tipo_de_Tasa'].value_counts()
# Out:
# 1    77347
# 2     2948
# 3      211
# 4       55
# 5       33
# 6        1
# Name: Tipo_de_Tasa, dtype: int64

# %%
#Convertimos Columna Clase_deudor
# 'Deudor de la entidad' : 1,'Deudor nuevo en la entidad' : 2
mapeo_Clase_deudor = {'Deudor de la entidad' : 1,'Deudor nuevo en la entidad' : 2}

# Aplicar el mapeo a la columna 'Clase_deudor'
df_Bancolombia_copia['Clase_deudor'] = df_Bancolombia_copia['Clase_deudor'].map(mapeo_Clase_deudor)
df_Bancolombia_copia['Clase_deudor'].value_counts()
# Out:
# 1    76972
# 2     3623
# Name: Clase_deudor, dtype: int64

# %%
df_Bancolombia_copia = df_Bancolombia_copia.drop('Fecha_Corte', axis=1)
df_Bancolombia_copia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80595 entries, 0 to 80594
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Tipo_de_persona                   80595 non-null  int64
#  1   Sexo                              80595 non-null  int64
#  2   Tamaño_de_empresa                 80595 non-null  int64
#  3   Tipo_de_crédito                   80595 non-null  int64
#  4   Tipo_de_garantía                  80595 non-null  int64
#  5   Producto de crédito               80595 non-null  object
#  6   Plazo de crédito                  80595 non-null  object
#  7   Tasa_efectiva_promedio_ponderada  80595 non-null  float64
#  8   Antiguedad_de_la_empresa          80595 non-null  int64
#  9   Tipo_de_Tasa                      80595 non-null  int64
#  10  Rango_monto_desembolsado          80595 non-null  object
#  11  Clase_deudor                      80595 non-null  int64
#  12  Codigo_CIIU                       80595 non-null  int64
#  13  Codigo_Municipio                  80595 non-null  float64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 9.2+ MB

# %%
df_filtrado = df_Bancolombia_copia[df_Bancolombia_copia['Tasa_efectiva_promedio_ponderada'] == 0]
df_filtrado.shape
# Out:
# (677756, 14)

# %% [markdown]
# ## Correlacion de variables

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#correlacion entre las variables
df_numerico = df_Bancolombia_copia.select_dtypes(exclude=['object'])
fig = plt.figure(figsize=(15,10))
sns.heatmap(df_numerico.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Escalamos los datos

# %%
from sklearn.preprocessing import StandardScaler
# Inicializa el escalador
scaler = StandardScaler()
# Aplica la estandarización a todas las columnas numéricas
df_numerico_escalado = pd.DataFrame(scaler.fit_transform(df_numerico), columns=df_numerico.columns)
df_numerico_escalado.head()
# Out:
#    Tipo_de_persona      Sexo  Tamaño_de_empresa  Tipo_de_crédito  \
# 0         1.508273  1.305798           1.977638         1.276090
# 1        -0.663010  0.097370          -0.575766        -0.625376
# 2        -0.663010  0.097370          -0.575766        -0.625376
# 3        -0.663010 -1.111058          -0.575766        -0.625376
# 4         1.508273  1.305798           1.977638         1.276090
#
#    Tipo_de_garantía  Tasa_efectiva_promedio_ponderada  \
# 0         -0.919667                          0.829146
# 1         -0.919667                          0.918003
# 2          1.053724                          0.829146
# 3          1.053724                         -1.319732
# 4         -0.919667                          0.831957
#
#    Antiguedad_de_la_empresa  Tipo_de_Tasa  Clase_deudor  Codigo_CIIU  \
# 0                  3.227303     -0.189219     -0.216954     1.490365
# 1                 -0.582728     -0.189219     -0.216954     1.515377
# 2                 -0.582728     -0.189219     -0.216954     0.550477
# 3                 -0.582728     -0.189219     -0.216954    -1.220592
# 4                  0.687282     -0.189219     -0.216954     1.319126
#
#    Codigo_Municipio
# 0         -0.744948
# 1         -0.956116
# 2         -0.528254
# 3         -0.952071
# 4         -0.744948

# %%
columnas_a_eliminar = ['Codigo_CIIU','Codigo_Municipio']

# Utiliza el método drop para eliminar las columnas
df_numerico_escalado =df_numerico_escalado.drop(columnas_a_eliminar, axis=1)
df_numerico_escalado.head()
# Out:
#    Tipo_de_persona      Sexo  Tamaño_de_empresa  Tipo_de_crédito  \
# 0         1.508273  1.305798           1.977638         1.276090
# 1        -0.663010  0.097370          -0.575766        -0.625376
# 2        -0.663010  0.097370          -0.575766        -0.625376
# 3        -0.663010 -1.111058          -0.575766        -0.625376
# 4         1.508273  1.305798           1.977638         1.276090
#
#    Tipo_de_garantía  Tasa_efectiva_promedio_ponderada  \
# 0         -0.919667                          0.829146
# 1         -0.919667                          0.918003
# 2          1.053724                          0.829146
# 3          1.053724                         -1.319732
# 4         -0.919667                          0.831957
#
#    Antiguedad_de_la_empresa  Tipo_de_Tasa  Clase_deudor
# 0                  3.227303     -0.189219     -0.216954
# 1                 -0.582728     -0.189219     -0.216954
# 2                 -0.582728     -0.189219     -0.216954
# 3                 -0.582728     -0.189219     -0.216954
# 4                  0.687282     -0.189219     -0.216954

# %%
df_bancolombia.head()
# Out:
#   Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# 0  01/12/2023        Jurídica  No aplica   Mediana empresa
# 1  20/10/2023         Natural   Femenino         No aplica
# 2  01/12/2023         Natural   Femenino         No aplica
# 3  29/09/2023         Natural  Masculino         No aplica
# 4  24/11/2023        Jurídica  No aplica   Mediana empresa
#
#        Tipo_de_crédito             Tipo_de_garantía  \
# 0  Comercial ordinario  Garantia idónea o no idónea
# 1              Consumo  Garantia idónea o no idónea
# 2              Consumo                 Sin garantia
# 3              Consumo                 Sin garantia
# 4  Comercial ordinario  Garantia idónea o no idónea
#
#                                  Producto de crédito  \
# 0                     Tarjeta de crédito empresarial
# 1      Sobregiro en cuenta corriente persona natural
# 2  Tarjeta de crédito para ingresos superiores a ...
# 3  Tarjeta de crédito para ingresos superiores a ...
# 4  Sobregiro en cuenta corriente persona jurídica...
#
#                Plazo de crédito  Tasa_efectiva_promedio_ponderada  \
# 0  Consumos entre 25 y 36 meses                             38.21
# 1                 Hasta 30 días                             39.79
# 2    Consumos entre 2 y 6 meses                             38.21
# 3             Consumos a un mes                              0.00
# 4                 Hasta 30 días                             38.26
#
#    margen_adicional  Montos_desembolsados  Numero_de_creditos_desembolsados  \
# 0               0.0            3538866.93                               5.0
# 1               0.0             480291.09                               2.0
# 2               0.0             353840.00                               1.0
# 3               0.0           14806418.00                              29.0
# 4               0.0           76230556.86                              10.0
#
#   Antiguedad_de_la_empresa Tipo_de_Tasa  \
# 0               0 a 5 años           FS
# 1             No aplica(1)           FS
# 2             No aplica(1)           FS
# 3             No aplica(1)           FS
# 4           más de 10 años           FS
#
#                       Rango_monto_desembolsado          Clase_deudor  \
# 0      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 1                                Hasta 1 SMLMV  Deudor de la entidad
# 2                                Hasta 1 SMLMV  Deudor de la entidad
# 3      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 4  Mayor a 12 SMLMV y menor o igual a 25 SMLMV  Deudor de la entidad
#
#    Codigo_CIIU  Codigo_Municipio
# 0         8544           11001.0
# 1         8622            5154.0
# 2         5613           17001.0
# 3           90            5266.0
# 4         8010           11001.0

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(df_numerico_escalado)
pca_data_scaled = pca.transform(df_numerico_escalado)
pca_data_scaled
# Out:
# array([[ 4.13553696e+00, -1.26799940e-01, -1.04117271e+00, ...,
#          9.53874974e-01, -1.07339981e+00,  5.49176573e-01],
#        [-8.82239238e-01, -5.47822812e-01, -1.17055527e+00, ...,
#         -5.85527777e-01, -5.71215333e-02,  2.76278554e-01],
#        [-1.28764677e+00,  2.89447325e-01, -5.33523230e-01, ...,
#         -5.37220332e-01,  7.16969884e-04,  1.82551518e-01],
#        ...,
#        [ 3.79208449e+00,  1.90630879e+00, -6.26520277e-01, ...,
#          7.10780939e-03, -4.62243140e-01,  1.38513596e-03],
#        [-1.19961153e+00, -1.65642154e-01,  1.50998669e+00, ...,
#         -5.65925599e-01,  3.44893935e-02,  1.67154903e-01],
#        [ 3.15639142e+00, -7.06790570e-01,  1.01673819e+00, ...,
#         -1.50268064e-01, -7.24514882e-02, -8.50577024e-02]])

# %%
var = pca.explained_variance_ratio_
print(var)
# Out:
# [0.49239099 0.12345156 0.11127068 0.10006039 0.08450393 0.0324887
#  0.0287611  0.01996923 0.00710341]

# %%
import numpy as np
cum_var = np.cumsum(np.round(var, decimals=4)*100)
plt.figure(figsize=(10,10))
plt.plot(cum_var, 'r-x')
plt.show()

# %% [markdown]
# viendo la grafica nos quedamos con las columnas del 0-3

# %%
pca_data_standard = pd.DataFrame(pca_data_scaled)
pca_data_standard.drop([4,5,6,7,8],axis=1, inplace=True)

# %%
pca_data_standard
# Out:
#               0         1         2         3
# 0      4.135537 -0.126800 -1.041173 -0.551826
# 1     -0.882239 -0.547823 -1.170555  0.156886
# 2     -1.287647  0.289447 -0.533523  0.212071
# 3     -1.707873 -0.194456  1.519604  0.131768
# 4      3.068241 -0.251106 -1.029446 -0.385038
# ...         ...       ...       ...       ...
# 80590  2.476213  0.629397 -0.557011 -0.314326
# 80591  3.331639 -0.663060  0.971752 -0.617312
# 80592  3.792084  1.906309 -0.626520  2.836918
# 80593 -1.199612 -0.165642  1.509987  0.017810
# 80594  3.156391 -0.706791  1.016738 -0.579553
#
# [80595 rows x 4 columns]

# %% [markdown]
# ## Clustering

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# ## K-Means
# # Con PCA

# %%
Sum_of_squared_distances = []
silhouette_scores = []
K = range(2,15)
for _ in K:
    km = KMeans(n_clusters = _)
    y = km.fit_predict(pca_data_standard)
    Sum_of_squared_distances.append(km.inertia_)
    silhouette_scores.append(silhouette_score(pca_data_standard,y))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('K')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# posiblemente sean de 3 clustering segun la grafica
# verificamos graficanfo el coeficiente de silueta

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(K, silhouette_scores, 'rx-')
plt.xlabel('K')
plt.ylabel('coeficiente de silueta')
plt.show()

# %% [markdown]
# serian 4 clustering segun la grafica
# ## Calculamos el coheficiente de Silueta y guardamos los resultados en df_bancombia

# %%
km = KMeans(n_clusters = 4)
y = km.fit_predict(pca_data_standard)
print(silhouette_score(pca_data_standard, y))
df_bancolombia['k_means_pca'] = y
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 0.6719141365487133

# %%
df_bancolombia.head()
# Out:
#   Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# 0  01/12/2023        Jurídica  No aplica   Mediana empresa
# 1  20/10/2023         Natural   Femenino         No aplica
# 2  01/12/2023         Natural   Femenino         No aplica
# 3  29/09/2023         Natural  Masculino         No aplica
# 4  24/11/2023        Jurídica  No aplica   Mediana empresa
#
#        Tipo_de_crédito             Tipo_de_garantía  \
# 0  Comercial ordinario  Garantia idónea o no idónea
# 1              Consumo  Garantia idónea o no idónea
# 2              Consumo                 Sin garantia
# 3              Consumo                 Sin garantia
# 4  Comercial ordinario  Garantia idónea o no idónea
#
#                                  Producto de crédito  \
# 0                     Tarjeta de crédito empresarial
# 1      Sobregiro en cuenta corriente persona natural
# 2  Tarjeta de crédito para ingresos superiores a ...
# 3  Tarjeta de crédito para ingresos superiores a ...
# 4  Sobregiro en cuenta corriente persona jurídica...
#
#                Plazo de crédito  Tasa_efectiva_promedio_ponderada  \
# 0  Consumos entre 25 y 36 meses                             38.21
# 1                 Hasta 30 días                             39.79
# 2    Consumos entre 2 y 6 meses                             38.21
# 3             Consumos a un mes                              0.00
# 4                 Hasta 30 días                             38.26
#
#    margen_adicional  Montos_desembolsados  Numero_de_creditos_desembolsados  \
# 0               0.0            3538866.93                               5.0
# 1               0.0             480291.09                               2.0
# 2               0.0             353840.00                               1.0
# 3               0.0           14806418.00                              29.0
# 4               0.0           76230556.86                              10.0
#
#   Antiguedad_de_la_empresa Tipo_de_Tasa  \
# 0               0 a 5 años           FS
# 1             No aplica(1)           FS
# 2             No aplica(1)           FS
# 3             No aplica(1)           FS
# 4           más de 10 años           FS
#
#                       Rango_monto_desembolsado          Clase_deudor  \
# 0      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 1                                Hasta 1 SMLMV  Deudor de la entidad
# 2                                Hasta 1 SMLMV  Deudor de la entidad
# 3      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 4  Mayor a 12 SMLMV y menor o igual a 25 SMLMV  Deudor de la entidad
#
#    Codigo_CIIU  Codigo_Municipio  k_means_pca
# 0         8544           11001.0            2
# 1         8622            5154.0            1
# 2         5613           17001.0            1
# 3           90            5266.0            1
# 4         8010           11001.0            2

# %% [markdown]
# ## K-Means
# # Sin PCA

# %%
Sum_of_squared_distances = []
silhouette_scores = []
K = range(2,15)
for _ in K:
    km = KMeans(n_clusters = _)
    y = km.fit_predict(df_numerico_escalado)
    Sum_of_squared_distances.append(km.inertia_)
    silhouette_scores.append(silhouette_score(df_numerico_escalado,y))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('K')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# segun esta grafica pueden ser 4, graficamos ahora el coeficiente de silueta

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(K, silhouette_scores, 'rx-')
plt.xlabel('K')
plt.ylabel('silhouette score')
plt.show()

# %% [markdown]
# en ambas graficas corresponde a 4 Clustering

# %%
km = KMeans(n_clusters = 4)
y = km.fit_predict(df_numerico_escalado)
print(silhouette_score(df_numerico_escalado, y))
df_bancolombia['k_means'] = y
df_bancolombia.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 0.43299924354447156
#   Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# 0  01/12/2023        Jurídica  No aplica   Mediana empresa
# 1  20/10/2023         Natural   Femenino         No aplica
# 2  01/12/2023         Natural   Femenino         No aplica
# 3  29/09/2023         Natural  Masculino         No aplica
# 4  24/11/2023        Jurídica  No aplica   Mediana empresa
#
#        Tipo_de_crédito             Tipo_de_garantía  \
# 0  Comercial ordinario  Garantia idónea o no idónea
# 1              Consumo  Garantia idónea o no idónea
# 2              Consumo                 Sin garantia
# 3              Consumo                 Sin garantia
# 4  Comercial ordinario  Garantia idónea o no idónea
#
#                                  Producto de crédito  \
# 0                     Tarjeta de crédito empresarial
# 1      Sobregiro en cuenta corriente persona natural
# 2  Tarjeta de crédito para ingresos superiores a ...
# 3  Tarjeta de crédito para ingresos superiores a ...
# 4  Sobregiro en cuenta corriente persona jurídica...
#
#                Plazo de crédito  Tasa_efectiva_promedio_ponderada  \
# 0  Consumos entre 25 y 36 meses                             38.21
# 1                 Hasta 30 días                             39.79
# 2    Consumos entre 2 y 6 meses                             38.21
# 3             Consumos a un mes                              0.00
# 4                 Hasta 30 días                             38.26
#
#    margen_adicional  Montos_desembolsados  Numero_de_creditos_desembolsados  \
# 0               0.0            3538866.93                               5.0
# 1               0.0             480291.09                               2.0
# 2               0.0             353840.00                               1.0
# 3               0.0           14806418.00                              29.0
# 4               0.0           76230556.86                              10.0
#
#   Antiguedad_de_la_empresa Tipo_de_Tasa  \
# 0               0 a 5 años           FS
# 1             No aplica(1)           FS
# 2             No aplica(1)           FS
# 3             No aplica(1)           FS
# 4           más de 10 años           FS
#
#                       Rango_monto_desembolsado          Clase_deudor  \
# 0      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 1                                Hasta 1 SMLMV  Deudor de la entidad
# 2                                Hasta 1 SMLMV  Deudor de la entidad
# 3      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 4  Mayor a 12 SMLMV y menor o igual a 25 SMLMV  Deudor de la entidad
#
#    Codigo_CIIU  Codigo_Municipio  k_means_pca  k_means
# 0         8544           11001.0            2        1
# 1         8622            5154.0            1        2
# 2         5613           17001.0            1        0
# 3           90            5266.0            1        0
# 4         8010           11001.0            2        1

# %%
from google.colab import files

# Supongamos que tienes un DataFrame llamado df

# Guarda el DataFrame como un archivo CSV
df_bancolombia.to_csv('Bancolombia_Clustering_5.csv', index=False)

# Descarga el archivo CSV
files.download('Bancolombia_Clustering_5.csv')

# %%
df_clustering=pd.read_csv('Bancolombia_Clustering_5.csv')
df_clustering.head()
# Out:
#   Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# 0  01/12/2023        Jurídica  No aplica   Mediana empresa
# 1  20/10/2023         Natural   Femenino         No aplica
# 2  01/12/2023         Natural   Femenino         No aplica
# 3  29/09/2023         Natural  Masculino         No aplica
# 4  24/11/2023        Jurídica  No aplica   Mediana empresa
#
#        Tipo_de_crédito             Tipo_de_garantía  \
# 0  Comercial ordinario  Garantia idónea o no idónea
# 1              Consumo  Garantia idónea o no idónea
# 2              Consumo                 Sin garantia
# 3              Consumo                 Sin garantia
# 4  Comercial ordinario  Garantia idónea o no idónea
#
#                                  Producto de crédito  \
# 0                     Tarjeta de crédito empresarial
# 1      Sobregiro en cuenta corriente persona natural
# 2  Tarjeta de crédito para ingresos superiores a ...
# 3  Tarjeta de crédito para ingresos superiores a ...
# 4  Sobregiro en cuenta corriente persona jurídica...
#
#                Plazo de crédito  Tasa_efectiva_promedio_ponderada  \
# 0  Consumos entre 25 y 36 meses                             38.21
# 1                 Hasta 30 días                             39.79
# 2    Consumos entre 2 y 6 meses                             38.21
# 3             Consumos a un mes                              0.00
# 4                 Hasta 30 días                             38.26
#
#    margen_adicional  Montos_desembolsados  Numero_de_creditos_desembolsados  \
# 0               0.0            3538866.93                               5.0
# 1               0.0             480291.09                               2.0
# 2               0.0             353840.00                               1.0
# 3               0.0           14806418.00                              29.0
# 4               0.0           76230556.86                              10.0
#
#   Antiguedad_de_la_empresa Tipo_de_Tasa  \
# 0               0 a 5 años           FS
# 1             No aplica(1)           FS
# 2             No aplica(1)           FS
# 3             No aplica(1)           FS
# 4           más de 10 años           FS
#
#                       Rango_monto_desembolsado          Clase_deudor  \
# 0      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 1                                Hasta 1 SMLMV  Deudor de la entidad
# 2                                Hasta 1 SMLMV  Deudor de la entidad
# 3      Mayor a 1 SMLMV menor o igual a 3 SMLMV  Deudor de la entidad
# 4  Mayor a 12 SMLMV y menor o igual a 25 SMLMV  Deudor de la entidad
#
#    Codigo_CIIU  Codigo_Municipio  k_means_pca  k_means
# 0         8544           11001.0            2        1
# 1         8622            5154.0            1        2
# 2         5613           17001.0            1        0
# 3           90            5266.0            1        0
# 4         8010           11001.0            2        1

# %% [markdown]
# comparamos coeficiente de silueta (con PCA=0.4341) (sin PCA=0.44104)
